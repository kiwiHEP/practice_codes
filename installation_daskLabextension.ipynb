# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %%
conda install jupyterlab nodejs
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ruchi/anaconda3
#
#   added / updated specs:
#     - jupyterlab
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.12.0               |   py39h06a4308_0        14.5 MB
#     libgcc-7.2.0               |       h69d50b8_2         269 KB
#     nodejs-6.11.2              |       h3db8ef7_0         9.4 MB
#     ------------------------------------------------------------
#                                            Total:        24.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgcc             pkgs/main/linux-64::libgcc-7.2.0-h69d50b8_2
#   nodejs             pkgs/main/linux-64::nodejs-6.11.2-h3db8ef7_0
#
# The following packages will be UPDATED:
#
#   conda                               4.10.3-py39h06a4308_0 --> 4.12.0-py39h06a4308_0
#
#
#
# Downloading and Extracting Packages
# conda-4.12.0         | 14.5 MB   | ##################################### | 100%
# libgcc-7.2.0         | 269 KB    | ##################################### | 100%
# nodejs-6.11.2        | 9.4 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install dask-labextension

# %%
#jupyter labextension install dask-labextension

# %%
from dask.distributed import Client
Client = Client()
Client
# Out:
# <Client: 'tcp://127.0.0.1:44327' processes=4 threads=8, memory=7.70 GiB>

# %%
import dask.array as da

x = da.random.random((10000,10000), chunks="16 MiB")
x
# Out:
# dask.array<random_sample, shape=(10000, 10000), dtype=float64, chunksize=(1250, 1250), chunktype=numpy.ndarray>

# %%
y = (x + x.T) - x.mean(axis=0)
y.sum().compute()
# Out:
# 50000847.68858734

# %%
conda install jupyterlab
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge nodejs
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ruchi/anaconda3
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.12.0               |   py39hf3d152e_0        1014 KB  conda-forge
#     nodejs-6.13.1              |                0        11.9 MB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/linux-64::python_abi-3.9-2_cp39
#
# The following packages will be UPDATED:
#
#   nodejs                pkgs/main::nodejs-6.11.2-h3db8ef7_0 --> conda-forge::nodejs-6.13.1-0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-4.12.0-py39h06a4308_0 --> conda-forge::conda-4.12.0-py39hf3d152e_0
#
#
#
# Downloading and Extracting Packages
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# nodejs-6.13.1        | 11.9 MB   | ##################################### | 100%
# conda-4.12.0         | 1014 KB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
